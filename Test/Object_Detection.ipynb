jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1807.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db915.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db915.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1813.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1813.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2895.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2895.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db242.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db242.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1344.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1344.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1422.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1422.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db524.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db524.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1436.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1436.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db530.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db530.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db256.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db256.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1350.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1350.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2659.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2659.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2881.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2881.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1378.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1378.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2671.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2671.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2117.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2117.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db518.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db518.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2103.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2103.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2665.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2665.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1387.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1387.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db281.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db281.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2856.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2856.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2842.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2842.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1393.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1393.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db295.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db295.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2739.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2739.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1230.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1230.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db336.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db336.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db450.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db450.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1556.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1556.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db444.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db444.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1542.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1542.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1224.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1224.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db322.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db322.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db72.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db72.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2705.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2705.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2063.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2063.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db478.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db478.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2077.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2077.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db66.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db66.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2711.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2711.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1218.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1218.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2922.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2922.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1595.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1595.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db493.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db493.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1581.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1581.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db487.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db487.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2088.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2088.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db99.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db99.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2936.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2936.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db3143.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db3143.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1754.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1754.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db652.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db652.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db134.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db134.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1032.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1032.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db120.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db120.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1026.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1026.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1740.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1740.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1998.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1998.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db646.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db646.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2249.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2249.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1768.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1768.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2261.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2261.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2507.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2507.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db108.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db108.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2513.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2513.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db2275.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db2275.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db691.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db691.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1797.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1797.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db849.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db849.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db685.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db685.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1783.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1783.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1973.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1973.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db875.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db875.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db1967.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db1967.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/train/db861.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/train/._db861.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/db/WebMarket_coco_gt_object.csv
#   inflating: /content/drive/MyDrive/Colab Notebooks/__MACOSX/db/._WebMarket_coco_gt_object.csv

# %%
import cv2
import os
import re
import pandas as pd
import numpy as np
import torch
import torchvision
from torchvision import transforms 
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SequentialSampler
from matplotlib import pyplot as plt

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/db/"
# Out:
# fasterrcnn_resnet50_fpn_best.pth  qr	 WebMarket_coco_gt_object.csv
# groundtruth			  train

# %% [markdown]
# ### 1. EDA
# #### Import annotation data¶
# Start by reading annotation data from the .csv file.

# %%
DATA = "/content/drive/MyDrive/Colab Notebooks/db/"

# %%
WEIGHTS_FILE = DATA+'/fasterrcnn_resnet50_fpn_best.pth'

# %%
trains_df= pd.read_csv(DATA+"WebMarket_coco_gt_object.csv")

# %%
trains_df.head()
# Out:
#   image_name    x1    y1    x2    y2   class
# 0    db1.jpg  1105   919  1315  1127  object
# 1    db1.jpg   191  1242   398  1469  object
# 2    db1.jpg  1587   697  1906   761  object
# 3    db1.jpg  1541   442  1845   541  object
# 4    db1.jpg  1252   505  1398   761  object

# %%
trains_df['x1'] = trains_df['x1'].astype(float)
trains_df['x2'] = trains_df['x2'].astype(float)
trains_df['y1'] = trains_df['y1'].astype(float)
trains_df['y2'] = trains_df['y2'].astype(float)

# %%
trains_df.head(10)
# Out:
#   image_name      x1      y1      x2      y2   class
# 0    db1.jpg  1105.0   919.0  1315.0  1127.0  object
# 1    db1.jpg   191.0  1242.0   398.0  1469.0  object
# 2    db1.jpg  1587.0   697.0  1906.0   761.0  object
# 3    db1.jpg  1541.0   442.0  1845.0   541.0  object
# 4    db1.jpg  1252.0   505.0  1398.0   761.0  object
# 5    db1.jpg   387.0   927.0   671.0  1112.0  object
# 6    db1.jpg   933.0   621.0  1085.0   766.0  object
# 7    db1.jpg  1325.0   932.0  1491.0  1137.0  object
# 8    db1.jpg  1091.0   592.0  1239.0   766.0  object
# 9    db1.jpg   778.0   646.0   924.0   763.0  object

# %%
trains_df['image_name'].nunique() # There are total 3151 unique image in training dataset
# Out:
# 3151

# %%
(trains_df['image_name'].value_counts()).max()  # maximum number of boxes in a single image are 264
# Out:
# 264

# %%
(trains_df['image_name'].value_counts()). min() # Minimum number of box in a single image is 1
# Out:
# 1

# %% [markdown]
# ### 2. Visualization
# #### Lets visualize some of the images with bounding box

# %%
ids = trains_df['image_name'].unique()
index = 4
dir = DATA+"train/"

id = ids[index]
image = cv2.imread(f'{dir}{id}', cv2.IMREAD_COLOR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB).astype(np.float32)

records = trains_df[trains_df['image_name'] == id]  #Getting all coordinates for the given image 
boxes = records[['x1', 'y1', 'x2', 'y2']].values
boxes[:, 2] = boxes[:, 0] + boxes[:, 2] # x1 + x2
boxes[:, 3] = boxes[:, 1] + boxes[:, 3] # y1 + y2

# %%
boxes = boxes.astype(np.int32)
sample = image.astype(np.int32)#.permute(1,2,0)

fig, ax = plt.subplots(1, 1, figsize=(16, 8))

for box in boxes:
    cv2.rectangle(sample,
                  (box[0], box[1]),
                  (box[2], box[3]),
                  (0, 255, 0), 3)
    
ax.set_axis_off()
ax.imshow(sample)

# %% [markdown]
# #### Splitting the data into train and validation set

# %%
image_ids = trains_df['image_name'].unique()
train_size = 0.8
valid_size=0.1

train_index = int(len(image_ids)*train_size)

train_df = image_ids[0:train_index]
df_rem = image_ids[train_index:]

valid_index = int(len(image_ids)*valid_size)

valid_df = image_ids[train_index:train_index+valid_index]
test_df = image_ids[train_index+valid_index:]

train_df = trains_df[trains_df['image_name'].isin(train_df)]
valid_df = trains_df[trains_df['image_name'].isin(valid_df)]
test_df = trains_df[trains_df['image_name'].isin(test_df)]

# %%
trans = transforms.Compose([transforms.ToTensor()])  # Apply transform to image

# %% [markdown]
# ### 3. Writing a custom dataset for our work
# ####   Writing a custom dataset for train and validation images

# %%
class MallDataset(Dataset):

    def __init__(self, dataframe, image_dir, transforms=None,train=True):
        super().__init__()

        self.image_ids = dataframe['image_name'].unique()
        self.df = dataframe
        self.image_dir = image_dir
        self.transforms = transforms
        self.train=train

    def __len__(self) -> int:
        return self.image_ids.shape[0]

    def __getitem__(self, index: int):

        image_id = self.image_ids[index]

        image = cv2.imread(f'{self.image_dir}{image_id}', cv2.IMREAD_COLOR)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB).astype(np.float32)
        image /= 255.0

        if self.transforms is not None:  #Apply transformation
            image = self.transforms(image)
        if(self.train==False):  # For test data
            return image, image_id

        #Else for train and validation data
        records = self.df[self.df['image_name'] == image_id]  #Getting all coordinates for the given image 
        boxes = records[['x1', 'y1', 'x2', 'y2']].values
        boxes[:, 2] = boxes[:, 0] + boxes[:, 2] # x1 + x2
        boxes[:, 3] = boxes[:, 1] + boxes[:, 3] # y1 + y2
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0]) # y2-y1 * x2-x1
        area = torch.as_tensor(area, dtype=torch.float32)

        # there is only one class
        labels = torch.ones((records.shape[0],), dtype=torch.int64)
        
        # suppose all instances are not crowd
        iscrowd = torch.zeros((records.shape[0],), dtype=torch.int64)
        
        target = {}
        target['boxes'] = boxes
        target['labels'] = labels
        target['image_name'] = torch.tensor([index])
        target['area'] = area
        target['iscrowd'] = iscrowd

        return image, target,image_id

# %%
train_dir = DATA+"train/"

# %%
class Averager:      ##Return the average loss 
    def __init__(self):
        self.current_total = 0.0
        self.iterations = 0.0

    def send(self, value):
        self.current_total += value
        self.iterations += 1

    @property
    def value(self):
        if self.iterations == 0:
            return 0
        else:
            return 1.0 * self.current_total / self.iterations

    def reset(self):
        self.current_total = 0.0
        self.iterations = 0.0
        
        
def collate_fn(batch):
    return tuple(zip(*batch))

train_dataset = MallDataset(train_df, train_dir, trans,True)
valid_dataset = MallDataset(valid_df, train_dir, trans,True)


# split the dataset in train and test set
indices = torch.randperm(len(train_dataset)).tolist()

train_data_loader = DataLoader(
    train_dataset,
    batch_size=4,
    shuffle=False,
    num_workers=2,
    collate_fn=collate_fn
)

valid_data_loader = DataLoader(
    valid_dataset,
    batch_size=2,
    shuffle=False,
    num_workers=2,
    collate_fn=collate_fn
)

#device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ### 4.Finetuuning the model
# #### Defining the model
#
# Faster R-CNN is a model that predicts both bounding boxes and class scores for potential objects in the image.

# %%
# load a model; pre-trained on COCO
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=False, pretrained_backbone=False)

# %% [markdown]
# In our case number of classes are 2, class 0 for background and class 1 for Mall Objects.

# %%
num_classes = 2  # 1 class (wheat) + background

# get number of input features for the classifier
in_features = model.roi_heads.box_predictor.cls_score.in_features

# replace the pre-trained head with a new one
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

# Load the trained weights
model.load_state_dict(torch.load(WEIGHTS_FILE))  ##Load pre trained weights
#model.eval()

#x = model.to(device)
# Out:
# <All keys matched successfully>

# %%
torch.cuda.empty_cache()

# %% [markdown]
# #### Lets train our model

# %%
model.train()
model.to(device)
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.01, momentum=0.9, weight_decay=0.00001)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.5)
#lr_scheduler = None

num_epochs = 5

loss_hist = Averager()
itr = 1

for epoch in range(num_epochs):
    loss_hist.reset()
    
    for images, targets, image_ids in train_data_loader:
        
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)   ##Return the loss

        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()

        loss_hist.send(loss_value)  #Average out the loss

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        if itr % 50 == 0:
            print(f"Iteration #{itr} loss: {loss_value}")

        itr += 1
    
    # update the learning rate
    if lr_scheduler is not None:
        lr_scheduler.step()

    print(f"Epoch #{epoch} loss: {loss_hist.value}")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Iteration #50 loss: 1.3473376035690308
# Iteration #100 loss: 1.1529531478881836
# Iteration #150 loss: 1.1169261932373047
# Iteration #200 loss: 0.9864567518234253
# Iteration #250 loss: 0.7565678358078003
# Iteration #300 loss: 0.7325274348258972
# Iteration #350 loss: 1.2468504905700684
# Iteration #400 loss: 0.8882126808166504
# Iteration #450 loss: 1.1155123710632324
# Iteration #500 loss: 1.5721409320831299
# Iteration #550 loss: 1.0282118320465088
# Iteration #600 loss: 1.1905758380889893
# Epoch #0 loss: 1.0496456384185762
# Iteration #650 loss: 0.9746454954147339
# Iteration #700 loss: 1.0309114456176758
# Iteration #750 loss: 1.0219939947128296
# Iteration #800 loss: 1.0720882415771484
# Iteration #850 loss: 0.8363074064254761
# Iteration #900 loss: 0.6248480081558228
# Iteration #950 loss: 0.7397536039352417
# Iteration #1000 loss: 1.0951924324035645
# Iteration #1050 loss: 1.0414760112762451
# Iteration #1100 loss: 0.584898054599762
# Iteration #1150 loss: 0.8622338175773621
# Iteration #1200 loss: 0.8504871726036072
# Iteration #1250 loss: 0.5015038251876831
# Epoch #1 loss: 0.8880158071007047
# Iteration #1300 loss: 0.767711341381073
# Iteration #1350 loss: 0.8433356881141663
# Iteration #1400 loss: 1.0041576623916626
# Iteration #1450 loss: 0.8334061503410339
# Iteration #1500 loss: 0.5513067245483398
# Iteration #1550 loss: 0.763982355594635
# Iteration #1600 loss: 0.7242541313171387
# Iteration #1650 loss: 0.7550909519195557
# Iteration #1700 loss: 0.8507645130157471
# Iteration #1750 loss: 0.8396761417388916
# Iteration #1800 loss: 0.8232758045196533
# Iteration #1850 loss: 0.6009806394577026
# Epoch #2 loss: 0.8038025808712793
# Iteration #1900 loss: 0.8491318821907043
# Iteration #1950 loss: 0.7657407522201538
# Iteration #2000 loss: 0.667864978313446
# Iteration #2050 loss: 0.8090473413467407
# Iteration #2100 loss: 0.8982149362564087
# Iteration #2150 loss: 0.5623311996459961
# Iteration #2200 loss: 0.5640785694122314
# Iteration #2250 loss: 0.9535394906997681
# Iteration #2300 loss: 0.8123539686203003
# Iteration #2350 loss: 0.8702954053878784
# Iteration #2400 loss: 0.7266770601272583
# Iteration #2450 loss: 0.6542097926139832
# Iteration #2500 loss: 0.8031473159790039
# Epoch #3 loss: 0.7503181451842899
# Iteration #2550 loss: 0.7200450301170349
# Iteration #2600 loss: 0.8661700487136841
# Iteration #2650 loss: 0.8018946647644043
# Iteration #2700 loss: 0.9794459939002991
# Iteration #2750 loss: 0.6281689405441284
# Iteration #2800 loss: 0.5948667526245117
# Iteration #2850 loss: 0.5145862698554993
# Iteration #2900 loss: 0.6994895935058594
# Iteration #2950 loss: 0.826265811920166
# Iteration #3000 loss: 0.7942854166030884
# Iteration #3050 loss: 0.6139158606529236
# Iteration #3100 loss: 0.652866005897522
# Iteration #3150 loss: 0.3998097777366638
# Epoch #4 loss: 0.720060047838423

# %%
print(torch.cuda.memory_summary(device=None, abbreviated=False))
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  730843 KB |    7351 MB |   99742 GB |   99742 GB |
# |       from large pool |  672665 KB |    7294 MB |   99352 GB |   99351 GB |
# |       from small pool |   58178 KB |      65 MB |     390 GB |     390 GB |
# |---------------------------------------------------------------------------|
# | Active memory         |  730843 KB |    7351 MB |   99742 GB |   99742 GB |
# |       from large pool |  672665 KB |    7294 MB |   99352 GB |   99351 GB |
# |       from small pool |   58178 KB |      65 MB |     390 GB |     390 GB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |   11358 MB |   11358 MB |   11528 MB |  174080 KB |
# |       from large pool |   11290 MB |   11290 MB |   11440 MB |  153600 KB |
# |       from small pool |      68 MB |      68 MB |      88 MB |   20480 KB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  588069 KB |    1863 MB |   36224 GB |   36224 GB |
# |       from large pool |  584807 KB |    1860 MB |   35798 GB |   35797 GB |
# |       from small pool |    3262 KB |       8 MB |     426 GB |     426 GB |
# |---------------------------------------------------------------------------|
# | Allocations           |     495    |     682    |    8432 K  |    8432 K  |
# |       from large pool |      79    |     181    |    2306 K  |    2305 K  |
# |       from small pool |     416    |     534    |    6126 K  |    6126 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     495    |     682    |    8432 K  |    8432 K  |
# |       from large pool |      79    |     181    |    2306 K  |    2305 K  |
# |       from small pool |     416    |     534    |    6126 K  |    6126 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |     108    |     108    |     124    |      16    |
# |       from large pool |      74    |      74    |      80    |       6    |
# |       from small pool |      34    |      34    |      44    |      10    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      43    |      78    |    4193 K  |    4193 K  |
# |       from large pool |      17    |      53    |    1508 K  |    1508 K  |
# |       from small pool |      26    |      36    |    2685 K  |    2685 K  |
# |===========================================================================|

# %%
test_dataset = MallDataset(test_df,train_dir, trans,False)

# %% [markdown]
# ### 5. Prediction
# #### Lets load the test data

# %%
test_data_loader = DataLoader( test_dataset, batch_size=4, shuffle=False)  ##Test dataloader

# %% [markdown]
# Set the threshold value for predicting bounding box.

# %%
detection_threshold = 0.45

# %%
def format_prediction_string(boxes, scores): ## Define the formate for storing prediction results
    pred_strings = []
    for j in zip(scores, boxes):
        pred_strings.append("{0:.4f} {1} {2} {3} {4}".format(j[0], j[1][0], j[1][1], j[1][2], j[1][3]))

    return " ".join(pred_strings)

# %%
## Lets make the prediction
results=[]
model.eval()

for images, image_ids in test_data_loader:    

    images = list(image.to(device) for image in images)
    outputs = model(images)

    for i, image in enumerate(images):

        boxes = outputs[i]['boxes'].data.cpu().numpy()    ##Formate of the output's box is [Xmin,Ymin,Xmax,Ymax]
        scores = outputs[i]['scores'].data.cpu().numpy()
        
        boxes = boxes[scores >= detection_threshold].astype(np.int32) #Compare the score of output with the threshold and
        scores = scores[scores >= detection_threshold]                    #slelect only those boxes whose score is greater
                                                                          # than threshold value
        image_id = image_ids[i]
        
        boxes[:, 2] = boxes[:, 2] - boxes[:, 0]         
        boxes[:, 3] = boxes[:, 3] - boxes[:, 1]         #Convert the box formate to [Xmin,Ymin,W,H]
        
        
            
        result = {                                     #Store the image id and boxes and scores in result dict.
            'image_id': image_id,
            'PredictionString': format_prediction_string(boxes, scores)
        }

        
        results.append(result)              #Append the result dict to Results list

# %%
test_df = pd.DataFrame(results, columns=['image_id', 'PredictionString'])
test_df.head()
# Out:
#      image_id                                   PredictionString
# 0  db2384.jpg  0.9996 3 16 319 325 0.9921 408 601 698 797 0.9...
# 1  db2385.jpg  0.9970 263 386 638 668 0.9959 17 347 290 656 0...
# 2  db2386.jpg  0.9949 1169 699 1423 1109 0.9942 674 110 1112 ...
# 3  db2387.jpg  0.9860 704 671 1121 947 0.9850 1045 692 1491 7...
# 4  db2388.jpg  0.9866 1239 718 1353 792 0.9848 989 438 1373 6...

# %% [markdown]
# Lets plot some of our prediction

# %%
i = 1 # index

# %%
id = test_df['image_id'][i]
dir = DATA+"train/"
image = cv2.imread(f'{dir}{id}', cv2.IMREAD_COLOR)
sample = cv2.cvtColor(image, cv2.COLOR_BGR2RGB).astype(np.float32)

# %%
boxes = outputs[i]['boxes'].data.cpu().numpy()
scores = outputs[i]['scores'].data.cpu().numpy()

boxes = boxes[scores >= detection_threshold]

boxes = boxes.astype(np.int32)
sample = image.astype(np.int32)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 8))

for box in boxes:
    cv2.rectangle(sample,
                  (box[0], box[1]),
                  (box[2], box[3]),
                  (0, 255, 0), 2)
    
ax.set_axis_off()
ax.imshow(sample)

# %%
test_df.to_csv('test_result.csv', index=False)
